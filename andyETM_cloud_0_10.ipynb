# %%
import pandas as pd
master_ETM = pd.read_csv('E:\master_ETM.csv')

# %%
print (master_ETM[(master_ETM['Scene Cloud Cover L1'] == 0.00)])
# Out:
#        Unnamed: 0                                        Browse Link  \
# 43         253385  https://landsatlook.usgs.gov/gen-browse?size=r...
# 106        617235  https://landsatlook.usgs.gov/gen-browse?size=r...
# 107        626632  https://landsatlook.usgs.gov/gen-browse?size=r...
# 190       1133992  https://landsatlook.usgs.gov/gen-browse?size=r...
# 364       2333410  https://landsatlook.usgs.gov/gen-browse?size=r...
# ...           ...                                                ...
# 16017     2842738  https://landsatlook.usgs.gov/gen-browse?size=r...
# 16025     2894545  https://landsatlook.usgs.gov/gen-browse?size=r...
# 16959      223093  https://landsatlook.usgs.gov/gen-browse?size=r...
# 17011      570533  https://landsatlook.usgs.gov/gen-browse?size=r...
# 17345     2764448  https://landsatlook.usgs.gov/gen-browse?size=r...
#
#                                      Display ID            Ordering ID  \
# ...

# %%
master_ETM_cloud_0 = (master_ETM[(master_ETM['Scene Cloud Cover L1'] == 0.00)])

# %%
print (master_ETM_cloud_0)
# Out:
#        Unnamed: 0                                        Browse Link  \
# 43         253385  https://landsatlook.usgs.gov/gen-browse?size=r...
# 106        617235  https://landsatlook.usgs.gov/gen-browse?size=r...
# 107        626632  https://landsatlook.usgs.gov/gen-browse?size=r...
# 190       1133992  https://landsatlook.usgs.gov/gen-browse?size=r...
# 364       2333410  https://landsatlook.usgs.gov/gen-browse?size=r...
# ...           ...                                                ...
# 16017     2842738  https://landsatlook.usgs.gov/gen-browse?size=r...
# 16025     2894545  https://landsatlook.usgs.gov/gen-browse?size=r...
# 16959      223093  https://landsatlook.usgs.gov/gen-browse?size=r...
# 17011      570533  https://landsatlook.usgs.gov/gen-browse?size=r...
# 17345     2764448  https://landsatlook.usgs.gov/gen-browse?size=r...
#
#                                      Display ID            Ordering ID  \
# ...

# %%
master_ETM_cloud_0.to_csv(r'E:\master_ETM_cloud_0.csv')

# %%
master_ETM_cloud_10 = (master_ETM[(master_ETM['Scene Cloud Cover L1'] < 10) & (master_ETM['Scene Cloud Cover L1'] > 0.0)])

# %%
print (master_ETM_cloud_10)
# Out:
#        Unnamed: 0                                        Browse Link  \
# 15          77949  https://landsatlook.usgs.gov/gen-browse?size=r...
# 19          97373  https://landsatlook.usgs.gov/gen-browse?size=r...
# 50         282863  https://landsatlook.usgs.gov/gen-browse?size=r...
# 71         399961  https://landsatlook.usgs.gov/gen-browse?size=r...
# 77         434101  https://landsatlook.usgs.gov/gen-browse?size=r...
# ...           ...                                                ...
# 17349     2789494  https://landsatlook.usgs.gov/gen-browse?size=r...
# 17353     2827005  https://landsatlook.usgs.gov/gen-browse?size=r...
# 17354     2834403  https://landsatlook.usgs.gov/gen-browse?size=r...
# 17355     2841846  https://landsatlook.usgs.gov/gen-browse?size=r...
# 17363     2886957  https://landsatlook.usgs.gov/gen-browse?size=r...
#
#                                      Display ID            Ordering ID  \
# ...

# %%
master_ETM_cloud_10.to_csv(r'E:\master_ETM_cloud_10.csv')
