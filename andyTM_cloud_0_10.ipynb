# %%
import pandas as pd
master_TM = pd.read_csv('E:\master_TM.csv')

# %%
master_TM[(master_TM['Scene Cloud Cover L1'] == 0.00)]
# Out:
#        Unnamed: 0                                        Browse Link  \
# 73         481930  https://landsatlook.usgs.gov/gen-browse?size=r...
# 186       1137160  https://landsatlook.usgs.gov/gen-browse?size=r...
# 357       2151566  https://landsatlook.usgs.gov/gen-browse?size=r...
# 390       2350881  https://landsatlook.usgs.gov/gen-browse?size=r...
# 433       2598799  https://landsatlook.usgs.gov/gen-browse?size=r...
# ...           ...                                                ...
# 14186      843399  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14275     1468996  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14357     1975226  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14358     1981868  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14416     2348626  https://landsatlook.usgs.gov/gen-browse?size=r...
#
#                                      Display ID            Ordering ID  \
# ...

# %%
master_TM_cloud_0 = (master_TM[(master_TM['Scene Cloud Cover L1'] == 0.0)])

# %%
master_TM_cloud_0
# Out:
#        Unnamed: 0                                        Browse Link  \
# 73         481930  https://landsatlook.usgs.gov/gen-browse?size=r...
# 186       1137160  https://landsatlook.usgs.gov/gen-browse?size=r...
# 357       2151566  https://landsatlook.usgs.gov/gen-browse?size=r...
# 390       2350881  https://landsatlook.usgs.gov/gen-browse?size=r...
# 433       2598799  https://landsatlook.usgs.gov/gen-browse?size=r...
# ...           ...                                                ...
# 14186      843399  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14275     1468996  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14357     1975226  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14358     1981868  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14416     2348626  https://landsatlook.usgs.gov/gen-browse?size=r...
#
#                                      Display ID            Ordering ID  \
# ...

# %%
master_TM_cloud_0.to_csv(r'E:\master_TM_cloud_0.csv')

# %%
master_TM_cloud_10 = (master_TM[(master_TM['Scene Cloud Cover L1'] < 10) & (master_TM['Scene Cloud Cover L1'] > 0.0)])

# %%
master_TM_cloud_10
# Out:
#        Unnamed: 0                                        Browse Link  \
# 14         149104  https://landsatlook.usgs.gov/gen-browse?size=r...
# 43         329549  https://landsatlook.usgs.gov/gen-browse?size=r...
# 97         606587  https://landsatlook.usgs.gov/gen-browse?size=r...
# 103        643799  https://landsatlook.usgs.gov/gen-browse?size=r...
# 106        665586  https://landsatlook.usgs.gov/gen-browse?size=r...
# ...           ...                                                ...
# 14495     2777335  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14497     2794459  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14499     2808343  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14500     2811079  https://landsatlook.usgs.gov/gen-browse?size=r...
# 14501     2817708  https://landsatlook.usgs.gov/gen-browse?size=r...
#
#                                      Display ID            Ordering ID  \
# ...

# %%
master_TM_cloud_10.to_csv(r'E:\master_TM_cloud_10.csv')
