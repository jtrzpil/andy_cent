# %%
import pandas as pd
master_OT = pd.read_csv('E:\master_OT.csv')

# %%
master_OT[(master_OT['Scene Cloud Cover L1'] == 0.00)]
# Out:
#       Unnamed: 0                                        Browse Link  \
# 3297       11881  https://landsatlook.usgs.gov/gen-browse?size=r...
# 3404     1069959  https://landsatlook.usgs.gov/gen-browse?size=r...
# 3433     1374526  https://landsatlook.usgs.gov/gen-browse?size=r...
# 3451     1547426  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6477      114804  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6652       29817  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6657       65603  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6661      112468  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6662      114805  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6670      211136  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6691      418014  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6692      427751  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6699      499193  https://landsatlook.usgs.gov/gen-browse?size=r...
# ...

# %%
master_OT_cloud_0 = (master_OT[(master_OT['Scene Cloud Cover L1'] == 0.0)])

# %%
print (master_OT_cloud_0)
# Out:
#       Unnamed: 0                                        Browse Link  \
# 3297       11881  https://landsatlook.usgs.gov/gen-browse?size=r...
# 3404     1069959  https://landsatlook.usgs.gov/gen-browse?size=r...
# 3433     1374526  https://landsatlook.usgs.gov/gen-browse?size=r...
# 3451     1547426  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6477      114804  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6652       29817  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6657       65603  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6661      112468  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6662      114805  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6670      211136  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6691      418014  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6692      427751  https://landsatlook.usgs.gov/gen-browse?size=r...
# 6699      499193  https://landsatlook.usgs.gov/gen-browse?size=r...
# ...

# %%
master_OT_cloud_0.to_csv(r'E:\master_OT_cloud_0.csv')

# %%
master_OT_cloud_10 = (master_OT[(master_OT['Scene Cloud Cover L1'] < 10) & (master_OT['Scene Cloud Cover L1'] > 0)])

# %%
print (master_OT_cloud_10)
# Out:
#       Unnamed: 0                                        Browse Link  \
# 3          38800  https://landsatlook.usgs.gov/gen-browse?size=r...
# 20        208586  https://landsatlook.usgs.gov/gen-browse?size=r...
# 22        226937  https://landsatlook.usgs.gov/gen-browse?size=r...
# 26        266391  https://landsatlook.usgs.gov/gen-browse?size=r...
# 31        316277  https://landsatlook.usgs.gov/gen-browse?size=r...
# ...          ...                                                ...
# 7365     1565806  https://landsatlook.usgs.gov/gen-browse?size=r...
# 7376     1667064  https://landsatlook.usgs.gov/gen-browse?size=r...
# 7388     1766260  https://landsatlook.usgs.gov/gen-browse?size=r...
# 7390     1801265  https://landsatlook.usgs.gov/gen-browse?size=r...
# 7393     1830334  https://landsatlook.usgs.gov/gen-browse?size=r...
#
#                                     Display ID            Ordering ID  \
# 3     LC08_L2SP_004068_20200529_20200820_02_T1  LC80040682020150LGN00
# ...

# %%
master_OT_cloud_10.to_csv(r'E:\master_OT_cloud_10.csv')
